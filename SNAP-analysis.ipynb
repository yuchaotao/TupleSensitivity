# %%
import pandas as pd
import numpy as np
report_sens = pd.read_csv('./result/report_sens.csv')
report_query = pd.read_csv('./result/report_query.csv')
report_DP = pd.read_csv('./result/report_DP.csv')
report_DP_limits = pd.read_csv('./result/report_DP_limits.csv')
queries = dict()
for qtype in ['triangle', '4path', '4cycle', '4star']:
    queries[qtype] = report_sens[report_sens['query'].str.startswith("q_%s"%qtype)]['query'].unique()
qtype_tex = {
    'triangle' : '$\qtri$',
    '4path' : '$\qpath$',
    '4cycle' : '$\qcycle$',
    '4star' : '$\qstar$'
}
qtypes = ['triangle', '4path', '4cycle', '4star']

# %%
def gen_table_meta_latex(queries, report_sens, report_query):
    qtypes = ['triangle', '4path', '4cycle', '4star']
    SETTINGS = 1
    
    #qtypes = ['triangle']
    #SETTINGS = 1
    
    tex_template = open('./result/table_meta.tex.template', 'r').read()
    filler = ''
    for qtype in qtypes:
        olevel_rows = sum([ \
                          sum([sum(len(tbl['attributes']) \
                        for tbl in eval(report_query.query('query=="%s"'%queries[qtype][i]).iloc[0]['table_dict']).values())]) \
                          for i in range(SETTINGS) ])
        filler += '\multirow{%d}{*}{%s} & '%(olevel_rows, qtype_tex[qtype])
        
        first_olevel = True
        for i in range(SETTINGS):
            if not first_olevel:
                filler += '& '
            qname = queries[qtype][i]
            info = report_query.query('query=="%s"'%qname).iloc[0]
            table_dict = eval(info['table_dict'])
            setting = '$s_%d$'%(i+1)
            qlevel_rows = sum([sum(len(tbl['attributes']) for tbl in table_dict.values())])
            median_mf = np.median([attr['mf'] for tbl in table_dict.values() for attr in tbl['attributes'].values()])
            filler += '\multirow{%d}{*}{%s} & '%(qlevel_rows, setting)
            filler += '\multirow{%d}{*}{%d} & '%(qlevel_rows, info['total_input'])
            filler += '\multirow{%d}{*}{%d} & '%(qlevel_rows, info['total_repr'])
            #filler += '\multirow{%d}{*}{%d} & '%(qlevel_rows, median_mf)
            filler += '\multirow{%d}{*}{%d} & '%(qlevel_rows, info['total_output'])
            first_qlevel = True
            for reln, reln_info in table_dict.items():
                tlevel_rows = len(reln_info['attributes'])
                if not first_qlevel:
                    filler += '& '*5
                filler += '\multirow{%d}{*}{%s} & '%(tlevel_rows, reln.replace('_', '\\_'))
                #filler += '\multirow{%d}{*}{reln} & '%(tlevel_rows)
                filler += '\multirow{%d}{*}{%d} & '%(tlevel_rows, reln_info['cnt'])
                filler += '\multirow{%d}{*}{%d} & '%(tlevel_rows, reln_info['repr'])
                first_tlevel = True
                for attr, attr_info in reln_info['attributes'].items():
                    if not first_tlevel:
                        filler += '& '*8
                    filler += '%s & '%attr
                    filler += '%d & '%attr_info['active']
                    filler += '%d & '%attr_info['repr']
                    filler += '%d '%attr_info['mf']
                    filler += '\\\\ \cline{9-12} \n'
                    first_tlevel = False
                filler += ' \cline{6-12} \n'
                first_qlevel = False
            filler += '\cline{2-12} \n'
            first_olevel = False
        filler += '\hline'
    table_tex = tex_template.replace('<filler>', filler)
    return table_tex

# %%
print(gen_table_meta_latex(queries, report_sens, report_query))
# Out:
# %\begin{table*}[t!]
# %\usepackage{longtable}
# %for \Yup
# %\usepackage{stmaryrd}
# %for \square \sqcap
# %\usepackage{mathabx}
# \def\qtri{q_\triangle}
# \def\qpath{q_\sqcap}
# \def\qcycle{q_\square}
# \def\qstar{q_\Yup}
# \def\tsens{TSens}
# \def\elastic{Elastic}
# %\begin{tabular}{|l|l|l|l|l|l|l|l|l|l|l|l|}
# \begin{longtable}{|l|l|l|l|l|l|l|l|l|l|l|l|}
# \hline
# qtype & setting & $|IN|$ & $|\reprdomain|$ & $|OUT|$ & relations & $|IN|$ & $\reprdomain$ & attr & $\actdomain$ & $\reprdomain$ & mf \\ \hline
# \endhead
# \multirow{6}{*}{$\qtri$} & \multirow{6}{*}{$s_1$} & \multirow{6}{*}{13520} & \multirow{6}{*}{62257} & \multirow{6}{*}{30699} & \multirow{2}{*}{source\_348\_circle\_dabfae} & \multirow{2}{*}{6830} & \multirow{2}{*}{13857} & A & 200 & 93 & 99 \\ \cline{9-12}
# & & & & & & & & B & 200 & 149 & 99 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_4d72cf} & \multirow{2}{*}{4818} & \multirow{2}{*}{18600} & C & 149 & 93 & 76 \\ \cline{9-12}
# & & & & & & & & B & 149 & 200 & 76 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_cd20fc} & \multirow{2}{*}{1872} & \multirow{2}{*}{29800} & C & 93 & 149 & 68 \\ \cline{9-12}
# & & & & & & & & A & 93 & 200 & 68 \\ \cline{9-12}
#  \cline{6-12}
# \cline{2-12}
# \hline\multirow{8}{*}{$\qpath$} & \multirow{8}{*}{$s_1$} & \multirow{8}{*}{14146} & \multirow{8}{*}{27391} & \multirow{8}{*}{17555419} & \multirow{2}{*}{source\_348\_circle\_dabfae} & \multirow{2}{*}{6830} & \multirow{2}{*}{0} & A & 200 & 0 & 99 \\ \cline{9-12}
# & & & & & & & & B & 200 & 149 & 99 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_4d72cf} & \multirow{2}{*}{4818} & \multirow{2}{*}{18600} & C & 149 & 93 & 76 \\ \cline{9-12}
# & & & & & & & & B & 149 & 200 & 76 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_cd20fc} & \multirow{2}{*}{1872} & \multirow{2}{*}{8791} & C & 93 & 149 & 68 \\ \cline{9-12}
# & & & & & & & & D & 93 & 59 & 68 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_9939a6} & \multirow{2}{*}{626} & \multirow{2}{*}{0} & E & 59 & 0 & 43 \\ \cline{9-12}
# & & & & & & & & D & 59 & 93 & 43 \\ \cline{9-12}
#  \cline{6-12}
# \cline{2-12}
# \hline\multirow{8}{*}{$\qcycle$} & \multirow{8}{*}{$s_1$} & \multirow{8}{*}{14146} & \multirow{8}{*}{54782} & \multirow{8}{*}{142903} & \multirow{2}{*}{source\_348\_circle\_dabfae} & \multirow{2}{*}{6830} & \multirow{2}{*}{8791} & A & 200 & 59 & 99 \\ \cline{9-12}
# & & & & & & & & B & 200 & 149 & 99 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_4d72cf} & \multirow{2}{*}{4818} & \multirow{2}{*}{18600} & C & 149 & 93 & 76 \\ \cline{9-12}
# & & & & & & & & B & 149 & 200 & 76 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_cd20fc} & \multirow{2}{*}{1872} & \multirow{2}{*}{8791} & C & 93 & 149 & 68 \\ \cline{9-12}
# & & & & & & & & D & 93 & 59 & 68 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_9939a6} & \multirow{2}{*}{626} & \multirow{2}{*}{18600} & D & 59 & 93 & 43 \\ \cline{9-12}
# & & & & & & & & A & 59 & 200 & 43 \\ \cline{9-12}
#  \cline{6-12}
# \cline{2-12}
# \hline\multirow{9}{*}{$\qstar$} & \multirow{9}{*}{$s_1$} & \multirow{9}{*}{18272} & \multirow{9}{*}{16008} & \multirow{9}{*}{786} & \multirow{2}{*}{source\_348\_circle\_dabfae} & \multirow{2}{*}{6830} & \multirow{2}{*}{899} & A & 29 & 29 & 99 \\ \cline{9-12}
# & & & & & & & & B & 28 & 31 & 99 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_4d72cf} & \multirow{2}{*}{4818} & \multirow{2}{*}{812} & C & 17 & 29 & 76 \\ \cline{9-12}
# & & & & & & & & B & 31 & 28 & 76 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{2}{*}{source\_348\_circle\_cd20fc} & \multirow{2}{*}{1872} & \multirow{2}{*}{493} & C & 29 & 17 & 68 \\ \cline{9-12}
# & & & & & & & & A & 29 & 29 & 68 \\ \cline{9-12}
#  \cline{6-12}
# & & & & & \multirow{3}{*}{tri\_source\_348\_circle\_9939a6} & \multirow{3}{*}{4752} & \multirow{3}{*}{13804} & C & 54 & 17 & 362 \\ \cline{9-12}
# & & & & & & & & A & 54 & 29 & 362 \\ \cline{9-12}
# & & & & & & & & B & 54 & 28 & 362 \\ \cline{9-12}
#  \cline{6-12}
# \cline{2-12}
# \hline
# \caption{Query meta stat for queries of 4 settings from 4 types. $\qtri$ is a triangle query, $\qpath$ is a path query of 4 nodes, $\qcycle$ is a 4-cycle query, $\qstar$ is a star query of 4 nodes}
# \end{longtable}
# %\end{tabular}
# %\end{table*}

# %%
def gen_sens_table_latex(queries, selected_query, report_sens, report_query):
    tex_template = open('./result/table_sens.tex.template', 'r').read()
    filler = ''
    
    for qtype in qtypes:
        filler += '%s '%qtype_tex[qtype]
        qname = queries[qtype][selected_query[qtype]]
        for algo in ['TSens', 'Elastic']:
            val = report_sens.query('algo=="{algo}" & query=="{qname}"'.format(algo=algo, qname=qname)).iloc[0]
            filler += '& %d'%val['sensitivity']
        for algo in ['TSens', 'Elastic']:
            val = report_sens.query('algo=="{algo}" & query=="{qname}"'.format(algo=algo, qname=qname)).iloc[0]
            filler += '& %.3f'%val['time']
        filler += '& %.3f'%report_query.query('query=="{qname}"'.format(qname=qname)).iloc[0]['avg_time']
        filler += '\\\\ \hline\n'
        
    table_tex = tex_template.replace('<filler>', filler)
    return table_tex

selected_query = {
    'triangle': 0,
    '4path': 0,
    '4cycle': 0,
    '4star': 0
}

# %%
print(gen_sens_table_latex(queries, selected_query, report_sens, report_query))
# Out:
# \begin{table}[t!]
# %for \Yup
# %\usepackage{stmaryrd}
# %for \square \sqcap
# %\usepackage{mathabx}
# \def\qtri{q_\triangle}
# \def\qpath{q_\sqcap}
# \def\qcycle{q_\square}
# \def\qstar{q_\Yup}
# \def\tsens{TSens}
# \def\elastic{Elastic}
# \begin{tabular}{|l|l|l|l|l|l|l|l|l|}
# \hline
# & \multicolumn{2}{c|}{Local Sensitivity} & \multicolumn{3}{c|}{Time (seconds)} \\ \cline{2-6}
# & \tsens & \elastic & \tsens & \elastic & Evaluation \\ \hline
# $\qtri$ & 87& 7524& 0.405& 0.007& 0.431\\ \hline
# $\qpath$ & 178923& 511632& 0.237& 0.010& 0.182\\ \hline
# $\qcycle$ & 2014& 511632& 0.618& 0.009& 0.465\\ \hline
# $\qstar$ & 34& 2723688& 0.604& 0.012& 0.175\\ \hline
# \end{tabular}
# \caption{Local sensitivity and time usage of 4 query types for TSens and Elastic. It also reports the query evaluation time for counting the output size.}
#     \vspace{-20pt}
# \end{table}

# %%
def gen_DP_table_latex(queries, selected_query, report_DP, report_query):
    df = report_DP.copy()
    df['time'] = df['avg_time']
    #df.loc[df['nosy_ans'] < 0, 'nosy_ans'] = 0
    df['relerror'] = df.apply(lambda x: np.median(np.absolute(np.array([max(i,0) for i in eval(x['nosy_ans_list'])]) - x['true_ans']) / x['true_ans']), axis=1)
    df['relbias'] = df.apply(lambda x: np.median(np.absolute(np.array(eval(x['bias_ans_list'])) - x['true_ans']) / x['true_ans']), axis=1)
    
    tex_template = open('./result/table_dp.tex.template', 'r').read()
    filler = ''
    
    for qtype in qtypes:
        filler += '%s &'%qtype_tex[qtype]
        qname = queries[qtype][selected_query[qtype]]
        filler += '%d &'%report_query.query('query=="{qname}"'.format(qname=qname)).iloc[0]['total_output']
        first_alevel = True
        for algo in ['TSensDP', 'PrivateSQL']:
            if not first_alevel:
                filler += '&'*2
            filler += ' %s '%algo
            val = df.query('algo=="{algo}" & query=="{qname}"'.format(algo=algo, qname=qname)).iloc[0]
            filler += '& {err:.2f}\\%  & {bias:.2f}\\% & {GS:.0f} & {time:.3f}'.format(GS=val['gsens'], bias=val['relbias']*100, err=val['relerror']*100, time=val['avg_time'])
            filler += '\\\\ \cline{3-7}'
            first_alevel = False
        filler += '\hline\n'        
    table_tex = tex_template.replace('<filler>', filler)
    return table_tex

selected_query = {
    'triangle': 0,
    '4path': 0,
    '4cycle': 0,
    '4star': 0
}

# %%
print(gen_DP_table_latex(queries, selected_query, report_DP, report_query))
# Out:
# \begin{table}[t!]
# \small
# %for \Yup
# %\usepackage{stmaryrd}
# %for \square \sqcap
# %\usepackage{mathabx}
# %\usepackage{makecell}
# \def\qtri{q_\triangle}
# \def\qpath{q_\sqcap}
# \def\qcycle{q_\square}
# \def\qstar{q_\Yup}
# \def\tsensdp{TSensDP}
# \def\privatesql{PrivateSQL}
# \begin{tabular}{|l|l|l|l|l|l|l|l|l|}
# \hline
#  Query & $|Q(D)|$ & Algorithm & \multicolumn{1}{c|}{Error} & \multicolumn{1}{c|}{Bias} & \multicolumn{1}{c|}{\makecell{Global \\ Sensitivity}} & \multicolumn{1}{c|}{Time}\\ \hline
# $\qtri$ &30699 & TSensDP & 1.50\%  & 1.47\% & 49 & 0.562\\ \cline{3-7}&& PrivateSQL & 19.12\%  & 0.00\% & 6732 & 0.230\\ \cline{3-7}\hline
# $\qpath$ &17555419 & TSensDP & 5.59\%  & 5.69\% & 17440 & 0.843\\ \cline{3-7}&& PrivateSQL & 2.25\%  & 0.00\% & 289476 & 10.340\\ \cline{3-7}\hline
# $\qcycle$ &142903 & TSensDP & 2.00\%  & 1.77\% & 167 & 0.792\\ \cline{3-7}&& PrivateSQL & 100.00\%  & 0.00\% & 289476 & 2.232\\ \cline{3-7}\hline
# $\qstar$ &786 & TSensDP & 19.02\%  & 16.16\% & 13 & 0.670\\ \cline{3-7}&& PrivateSQL & 30226.55\%  & 0.00\% & 2436984 & 0.290\\ \cline{3-7}\hline
# \end{tabular}
# \caption{Application to Differential Privacy: Comparing \TSensDP error to \PrivSQL error. Time is in seconds.}
#     \vspace{-20pt}
# \end{table}

# %%
def gen_dp_oracle_table_latex(queries, qtype, report_DP_limits, report_sens, measure='relerror'):
    import numpy as np
    algo = 'TSensDP'
    df = report_DP_limits.copy()
    df['time'] = df['avg_time']
    df.loc[df['nosy_ans'] < 0, 'nosy_ans'] = 0 
    df['relerror'] = np.absolute(df['nosy_ans'] - df['true_ans']) / df['true_ans']
    limits = sorted(df[df['query'].str.startswith("q_%s"%qtype)]['limit'].unique())
    tex_template = open('./result/table_dp_%s.tex.template'%'oracle', 'r').read()
    filler = ''
    filler += '\multirow{2}{*}{setting} & \multirow{2}{*}{LS} & \multicolumn{6}{c|}{$\ell$} \\\\ \\cline{3-8} \n&'
    for limit in limits:
        filler += '& %d\t'%limit
    filler += '\\\\ \\hline \n'
    for i in range(4):
        all_table_tstar = report_sens.query('algo=="TSens" & query=="{qname}"'.format(qname=queries[qtype][i]))['all_table_tstar'].to_list()[0]
        all_table_tstar = eval(re.sub(r'((tri_)?source.*?),', r"'\1',", all_table_tstar))
        for table_tstar in all_table_tstar:
            if table_tstar[0] == df.query('algo=="{algo}" & query=="{qname}"'.format(algo=algo, qname=queries[qtype][i]))['reln'].to_list()[0]:
                LS = table_tstar[2]
        filler += '$s_%d$ & %d\t'%(i+1, LS)
        for limit in limits:
            q = 'algo=="{algo}" & limit=="{limit}" & query=="{qname}"'.format(algo=algo, qname=queries[qtype][i], limit=limit)
            val = df.query(q)[measure].to_list()[0]
            filler += '& {val:.2f}\\%\t'.format(val=val*100)
        filler += '\\\\ \hline\n'
    table_tex = tex_template.replace('<filler>', filler).replace('<qtype>', qtype + ' queries')
    return table_tex

# %%
for qtype in ['triangle', '4path', '4cycle', '4star']:
    print(gen_dp_oracle_table_latex(queries, qtype, report_DP_limits, report_sens))
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-7b2ada56d969> in <module>()
#       1 for qtype in ['triangle', '4path', '4cycle', '4star']:
# ----> 2     print(gen_dp_oracle_table_latex(queries, qtype, report_DP_limits, report_sens))
#       3     print()
#
# <ipython-input-157-f447c8d4524b> in gen_dp_oracle_table_latex(queries, qtype, report_DP_limits, report_sens, measure)
#      15     for i in range(4):
#      16         all_table_tstar = report_sens.query('algo=="TSens" & query=="{qname}"'.format(qname=queries[qtype][i]))['all_table_tstar'].to_list()[0]
# ---> 17         all_table_tstar = eval(re.sub(r'((tri_)?source.*?),', r"'\1',", all_table_tstar))
#      18         for table_tstar in all_table_tstar:
#      19             if table_tstar[0] == df.query('algo=="{algo}" & query=="{qname}"'.format(algo=algo, qname=queries[qtype][i]))['reln'].to_list()[0]:
#
# NameError: name 're' is not defined
